# %%
import requests

cookies = {
    'gk_suid': '25213243',
    'bcp': 'b0376827-0ad9-49bf-97f5-0be8dad48ae7',
    'OptanonConsent': 'groups=C0001:1,C0002:1,C0003:1,C0004:1',
    'OptanonAlertBoxClosed': '2023-06-25T17:21:42.796Z',
    'bcp_generated': '1656177700014',
    'AMCVS_9E1005A551ED61CA0A490D45%40AdobeOrg': '1',
    'gpv': 'behance.net:search:projects',
    's_cc': 'true',
    'sign_up_prompt': 'true',
    's_ppv': '[%22www.behance.net/%22%2C100%2C0%2C14442%2C1920%2C1012%2C1920%2C1080%2C1%2C%22P%22]',
    's_sq': 'adbadobenonacdcprod%252Cadbbehanceprod%252Cadbadobeprototype%3D%2526c.%2526a.%2526activitymap.%2526page%253Dhttps%25253A%25252F%25252Fwww.behance.net%25252Fsearch%25252Fprojects%2526link%253Dd2d1d1d2d1d1h1d2d1d2d1d1B1-Creative%252520Fields%2526region%253Dheader%2526xy%253D14500%2526.activitymap%2526.a%2526.c',
    'AMCV_9E1005A551ED61CA0A490D45%40AdobeOrg': '870038026%7CMCMID%7C81562318874012416998171708220153301619%7CMCAID%7CNONE%7CMCOPTOUT-1656185098s%7CNONE%7CvVersion%7C5.0.0',
}

headers = {
    'authority': 'www.behance.net',
    'accept': '*/*',
    'x-bcp': 'b0376827-0ad9-49bf-97f5-0be8dad48ae7',
    'x-requested-with': 'XMLHttpRequest',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36',
    # Already added when you pass json=
    # 'content-type': 'application/json',
    'sec-gpc': '1',
    'origin': 'https://www.behance.net',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.behance.net/search/projects?field=architecture',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    # Requests sorts cookies= alphabetically
    # 'cookie': 'gk_suid=25213243; bcp=b0376827-0ad9-49bf-97f5-0be8dad48ae7; OptanonConsent=groups=C0001:1,C0002:1,C0003:1,C0004:1; OptanonAlertBoxClosed=2023-06-25T17:21:42.796Z; bcp_generated=1656177700014; AMCVS_9E1005A551ED61CA0A490D45%40AdobeOrg=1; gpv=behance.net:search:projects; s_cc=true; sign_up_prompt=true; s_ppv=[%22www.behance.net/%22%2C100%2C0%2C14442%2C1920%2C1012%2C1920%2C1080%2C1%2C%22P%22]; s_sq=adbadobenonacdcprod%252Cadbbehanceprod%252Cadbadobeprototype%3D%2526c.%2526a.%2526activitymap.%2526page%253Dhttps%25253A%25252F%25252Fwww.behance.net%25252Fsearch%25252Fprojects%2526link%253Dd2d1d1d2d1d1h1d2d1d2d1d1B1-Creative%252520Fields%2526region%253Dheader%2526xy%253D14500%2526.activitymap%2526.a%2526.c; AMCV_9E1005A551ED61CA0A490D45%40AdobeOrg=870038026%7CMCMID%7C81562318874012416998171708220153301619%7CMCAID%7CNONE%7CMCOPTOUT-1656185098s%7CNONE%7CvVersion%7C5.0.0',
}

json_data = {
    'query': '\n      query GetProjectSearchResults($query: query, $filter: SearchResultFilter, $first: Int!, $after: String) {\n        search(query: $query, type: PROJECT, filter: $filter, first: $first, after: $after) {\n          pageInfo {\n            hasNextPage\n            endCursor\n          }\n          nodes {\n            ... on Project {\n              id\n              colors {\n                r\n                g\n                b\n              }\n              isMatureReviewSubmitted\n              linkedAssetsCount\n              name\n              premium\n              isPrivate\n              publishedOn\n              isFounder\n              isFeatured\n              modifiedOn\n              adminFlags {\n                mature_lock\n                privacy_lock\n                dmca_lock\n                flagged_lock\n                privacy_violation_lock\n                trademark_lock\n                spam_lock\n                eu_ip_lock\n              }\n              features {\n                featuredOn\n                url\n                name\n                ribbon {\n                  image\n                  image2x\n                  image3x\n                }\n              }\n              slug\n              stats {\n                views {\n                  all\n                }\n                appreciations {\n                  all\n                }\n                comments {\n                  all\n                }\n              }\n              url\n              fields {\n                label\n              }\n              linkedAssets {\n                url\n                name\n                premium\n              }\n              matureAccess\n              hasMatureContent\n              owners {\n                images {\n                  size_50 {\n                    url\n                  }\n                  size_100 {\n                    url\n                  }\n                  size_115 {\n                    url\n                  }\n                  size_138 {\n                    url\n                  }\n                  size_230 {\n                    url\n                  }\n                  size_276 {\n                    url\n                  }\n                }\n                displayName\n                url\n                id\n                location\n                locationUrl\n                username\n                hasPremiumAccess\n                isProfileOwner\n              }\n              covers {\n                size_original {\n                  url\n                }\n                size_max_808 {\n                  url\n                }\n                size_808 {\n                  url\n                }\n                size_404 {\n                  url\n                }\n                size_202 {\n                  url\n                }\n                size_230 {\n                  url\n                }\n                size_115 {\n                  url\n                }\n              }\n            }\n          }\n          metaContent {\n            toolCard {\n              cta {\n                text\n                url\n              }\n              description\n              links {\n                text\n                url\n                type\n              }\n              slug\n              title\n            }\n            schoolCard {\n              cta {\n                text\n                url\n              }\n              description\n              slug\n            }\n            csam {\n              isCSAMViolation\n              description\n              helpResource\n              reportingOption\n            }\n          }\n        }\n      }\n    ',
    'variables': {
        'filter': {
            'field': 'architecture',
        },
        'first': 145,
    },
}

response = requests.post('https://www.behance.net/v3/graphql', cookies=cookies, headers=headers, json=json_data)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'data': {'search': {'pageInfo': {'hasNextPage': True, 'endCursor': 'MTQ2'},
#    'nodes': [{'id': 103580473,
#      'colors': {'r': 139, 'g': 114, 'b': 99},
#      'isMatureReviewSubmitted': None,
#      'linkedAssetsCount': 0,
#      'name': 'BRIDGE 18/2',
#      'premium': 0,
#      'isPrivate': False,
#      'publishedOn': 1600079888,
#      'isFounder': False,
#      'isFeatured': True,
#      'modifiedOn': 1656171010,
#      'adminFlags': None,
#      'features': [{'featuredOn': 1622417422,
#        'url': 'https://www.behance.net/galleries/architecture/architecture-visualization',
#        'name': 'Architecture Visualization',
#        'ribbon': {'image': 'https://a5.behance.net/c3d0aeed58fa407ef43dea6397250b6b4f3c7e08/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image2x': 'https://a5.behance.net/c3d0aeed58fa407ef43dea6397250b6b4f3c7e08/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['data', 'http_code'])

# %%
results_json = response.json()

# %%
has_next_page = results_json['data']['search']['pageInfo']['hasNextPage']

# %%
nodes = results_json['data']['search']['nodes']

# %%
nodes[0].keys()
# Out:
# dict_keys(['id', 'colors', 'isMatureReviewSubmitted', 'linkedAssetsCount', 'name', 'premium', 'isPrivate', 'publishedOn', 'isFounder', 'isFeatured', 'modifiedOn', 'adminFlags', 'features', 'slug', 'stats', 'url', 'fields', 'linkedAssets', 'matureAccess', 'hasMatureContent', 'owners', 'covers'])

# %%
48 * 3
# Out:
# 144
